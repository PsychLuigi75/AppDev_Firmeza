# %% [markdown]
# Exercise 1

# %%
#In the code below, which will never print regardless of the value for x? Edit the code to correct the error.
#As I'd check the code the error is the condition because it can't indicate the value whether if it is above the stated number.

x = int (input("Enter number: "))

if x >= 50:
    print('Above 50')
elif x >= 20:
    print('Above 20')
elif x >= 10:
    print('Above 10')
elif x > 0:
    print('Above 0')
else :
    print('Something else')
# Out:
# Enter number: 10
# Above 10

# %% [markdown]
# Exercise 2

# %%
#Write your salary computation to give an employee 1.5 times the hourly rate for hours worked above 40 hours. Example:
#Enter Hours: 45
#Enter Rate: 10
#Pay: 475.0

hrs = int (input("Enter Hours: "))
rate = float (input("Enter Rate: "))

if hrs > 40:
  rp = 40 * rate
  op = (hrs - 40) * rate * 1.5
  tp = rp + op

else:
  tp = hrs * rate

print("Pay: ",tp)
# Out:
# Enter Hours: 45
# Enter Rate: 10
# Pay:  475.0

# %% [markdown]
# CHALLENGE

# %%
#Write a program to prompt for a score between 0 and 100 and print a grade using the following table:

# Score             Grade
# [ 97, 100]        1.0
# [ 93,  97)        1.25
# [ 89,  93)        1.5
# [ 85,  89)        1.75
# [ 81,  85)        2.0
# [ 77,  81)        2.25
# [ 74,  77)        2.5
# [ 0,   74)        3.0

grade = int(input("Enter score: "))

if(grade >= 97):
  print("Your grade: 1.0")
elif(grade >= 93):
  print("Your grade: 1.25")
elif(grade >= 89):
  print("Your grade: 1.5")
elif(grade >= 85):
  print("Your grade: 1.75")
elif(grade >= 81):
  print("Your grade: 2.0")
elif(grade >= 77):
  print("Your grade: 2.25")
elif(grade >= 74):
  print("Your grade: 2.5")
elif(grade >= 0):
  print("Your grade: 3.0")
# Out:
# Enter score: 74
# Your grade: 2.5
