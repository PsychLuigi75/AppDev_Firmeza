# %% [markdown]
# Exersice 1

# %%
print('Hello world!')
#Print('Hello world!')
#The error in this line of code is the Print() syntax, because the uppercase is big.
# Out:
# Hello world!

# %%
print('Hello world!')
#print'Hello world!')
#The error in this line of code is the missing open parenthesis
# Out:
# Hello world!

# %%
print('Hello world!')
#print('Hello world!)
#The error in this line of code is missing singe qoutation mark
# Out:
# Hello world!

# %%
print('Hello world!')
#print('Hello world!'')
#The error in this line of code is there is another single qoutation mark
# Out:
# Hello world!

# %% [markdown]
# Exercise 2

# %%
x = 43
x = x + 1
print(x)
#There is no error this code
# Out:
# 44

# %% [markdown]
# Exercise 3

# %%
x = 43
x = x + 1
print(x)
#x = X + 1
#The error in this line of code is initialize variable name is small letter while in the expression is big letter.
# Out:
# 44
